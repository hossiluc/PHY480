# %%
from Class_implementation_3D import *
import pandas as pd

# %matplotlib inline

# %%
p2=planet(x0=-50, y0=50, z0=10, v0x=1, v0y=1, v0z=1, m=200, n_iter=100, tstep=8)
values=p2.orbit()

# %%
Data= {'X_pos': values[0][0:100], 'Y_pos': values[1][0:100], 'Z_pos': values[2][0:100], 'Theta': values[3][0:100]}
Formated_data = pd.DataFrame(data=Data)
Formated_data.head()
# Out:
#        X_pos      Y_pos      Z_pos     Theta
# 0 -50.000000  50.000000  10.000000  2.356194
# 1 -40.189807  56.189807  19.810193  2.191685
# 2 -28.819325  60.198157  31.180675  2.017293
# 3 -16.208007  61.614635  43.791993  1.828023
# 4  -2.794456  59.981427  57.205544  1.617351
